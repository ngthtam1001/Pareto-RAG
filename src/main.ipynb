# %% [markdown]
# ## Setup

# %%
import pandas as pd
import ast
import asyncio
import google.generativeai as genai
import numpy as np
from typing import List, Dict, Any
import torch
from tqdm import tqdm 
from transformers import AutoTokenizer, AutoModelForCausalLM
from sentence_transformers import SentenceTransformer
import os
import yaml
# Out:
# WARNING:tensorflow:From c:\Users\admin\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
df = pd.read_csv(r'C:\Users\admin\Desktop\AIO\ParetoRAG\data\validation_data.csv')
df = df.head(300)

# %% [markdown]
# ## Embedding

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SentenceTransformer('all-MiniLM-L6-v2')  
model = model.to(device)

# %%
BATCH_SIZE = 64

# %%
async def get_embeddings_batch(texts: List[str], batch_size: int = 32):
    embeddings = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i + batch_size]
        batch_emb = await asyncio.to_thread(model.encode, batch, convert_to_numpy=True)
        embeddings.extend(batch_emb)
    return np.array(embeddings)

# %%
async def process_row_async(row: pd.Series) -> List[Dict[str, Any]]:
    sentences_dict = ast.literal_eval(row.values[5])
    results = []
    question_id, question = row.values[0], row.values[1]
    
    for title, sentences in sentences_dict.items():
        contexts = [' '.join(s for s in sentences if s != sent) for sent in sentences]        
        core_embs = await get_embeddings_batch(sentences)
        context_embs = await get_embeddings_batch(contexts)
        weighted_embs = 0.8 * core_embs + 0.2 * context_embs
        
        results.extend([{
            'question_id': question_id,
            'question': question,
            'title': title,
            'sentence': sent,
            'weighted_embedding': w_emb
        } for sent, w_emb in zip(sentences, weighted_embs)])
    
    return results

# %%
async def process_all_rows(df: pd.DataFrame) -> pd.DataFrame:
    tasks = [process_row_async(row) for _, row in df.iterrows()]
    results = await tqdm.gather(*tasks, desc="Processing rows")
    all_results = [item for sublist in results for item in sublist]
    return pd.DataFrame(all_results)

# %%
embeddings_df = await process_all_rows(df)
# Out:
# Processing rows: 100%|██████████| 300/300 [01:47<00:00,  2.78it/s]

# %%
embeddings_df
# Out:
#                     question_id  \
# 0      5a8b57f25542995d1e6f1371
# 1      5a8b57f25542995d1e6f1371
# 2      5a8b57f25542995d1e6f1371
# 3      5a8b57f25542995d1e6f1371
# 4      5a8b57f25542995d1e6f1371
# ...                         ...
# 12803  5adfbca255429942ec259b2c
# 12804  5adfbca255429942ec259b2c
# 12805  5adfbca255429942ec259b2c
# 12806  5adfbca255429942ec259b2c
# 12807  5adfbca255429942ec259b2c
#
#                                                 question  \
# 0      Were Scott Derrickson and Ed Wood of the same ...
# 1      Were Scott Derrickson and Ed Wood of the same ...
# 2      Were Scott Derrickson and Ed Wood of the same ...
# 3      Were Scott Derrickson and Ed Wood of the same ...
# 4      Were Scott Derrickson and Ed Wood of the same ...
# ...                                                  ...
# 12803  When did the rock band that sang "All Join Han...
# 12804  When did the rock band that sang "All Join Han...
# 12805  When did the rock band that sang "All Join Han...
# 12806  When did the rock band that sang "All Join Han...
# 12807  When did the rock band that sang "All Join Han...
#
#                          title  \
# 0                  Adam Collis
# 1                  Adam Collis
# 2                  Adam Collis
# 3                  Adam Collis
# 4                  Adam Collis
# ...                        ...
# 12803  Tom Morello discography
# 12804  Tom Morello discography
# 12805  Tom Morello discography
# 12806  Tom Morello discography
# 12807  Tom Morello discography
#
#                                                 sentence  \
# 0      Adam Collis Adam Collis is an American filmmak...
# 1      Adam Collis  He attended the Duke University f...
# 2      Adam Collis  He also studied cinema at the Uni...
# 3      Adam Collis  Collis first work was the assista...
# 4      Adam Collis  In 1998, he played "Crankshaft" i...
# ...                                                  ...
# 12803  Tom Morello discography  After graduating "" f...
# 12804  Tom Morello discography  Later Adam Jones move...
# 12805  Tom Morello discography  In the late 80's More...
# 12806  Tom Morello discography  In 1991 Morello left ...
# 12807  Tom Morello discography  After Zack convinced ...
#
#                                       weighted_embedding
# 0      [-0.060843006, -0.07372631, 0.030862343, -0.04...
# 1      [-0.0066994987, -0.06440425, 0.049298123, -0.0...
# 2      [-0.01357059, -0.09846686, 0.007369948, -0.025...
# 3      [-0.12149089, -0.053364065, 0.029267848, -0.03...
# 4      [-0.08738548, -0.04439761, -0.032737877, -0.06...
# ...                                                  ...
# 12803  [-0.038539037, -0.06785561, -0.031276815, -0.0...
# 12804  [-0.105251186, -0.07850574, -0.06657188, -0.05...
# 12805  [-0.1281535, -0.02820184, -0.07985569, -0.0425...
# 12806  [-0.110214725, -0.046852585, -0.07335095, -0.0...
# 12807  [-0.13750131, -0.030298732, -0.046328366, -0.0...
#
# [12808 rows x 5 columns]

# %%
question_df = df[['question_id', 'question']]

async def add_question_embeddings(df: pd.DataFrame) -> pd.DataFrame:
    questions = df['question'].tolist()
    question_embeddings = await get_embeddings_batch(questions, batch_size=BATCH_SIZE)
    df['question_embedding'] = question_embeddings.tolist()
    return df

# %%
question_df = await add_question_embeddings(question_df)
question_df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_23540\1149838254.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['question_embedding'] = question_embeddings.tolist()
#                   question_id  \
# 0    5a8b57f25542995d1e6f1371
# 1    5a8c7595554299585d9e36b6
# 2    5a85ea095542994775f606a8
# 3    5adbf0a255429947ff17385a
# 4    5a8e3ea95542995a26add48d
# ..                        ...
# 295  5a835c9f5542992ef85e228a
# 296  5ae7edee554299540e5a56ad
# 297  5a8ee4315542990e94052ba7
# 298  5a8cb288554299585d9e3726
# 299  5adfbca255429942ec259b2c
#
#                                               question  \
# 0    Were Scott Derrickson and Ed Wood of the same ...
# 1    What government position was held by the woman...
# 2    What science fantasy young adult series, told ...
# 3    Are the Laleli Mosque and Esma Sultan Mansion ...
# 4    The director of the romantic comedy "Big Stone...
# ..                                                 ...
# 295  What army did the namesake of the ship launche...
# 296  The Church of the Guanche People was founded i...
# 297  What officially ended the first phase of the m...
# 298  The mass killing that took place at Oakland, C...
# 299  When did the rock band that sang "All Join Han...
#
#                                     question_embedding
# 0    [-0.07346513122320175, -0.01779698207974434, -...
# 1    [-0.06768488883972168, -0.04196927696466446, -...
# 2    [-0.011420877650380135, 0.02307860180735588, -...
# 3    [0.09680207818746567, 0.031308747828006744, -0...
# 4    [0.061934322118759155, -0.044251229614019394, ...
# ..                                                 ...
# 295  [-0.02701864205300808, 0.03475065529346466, -0...
# 296  [0.0434095524251461, -0.0071853455156087875, -...
# 297  [-0.08006496727466583, 0.030587373301386833, 0...
# 298  [0.11990100890398026, 0.04099593311548233, 0.0...
# 299  [-0.033925507217645645, -0.05026710778474808, ...
#
# [300 rows x 3 columns]

# %% [markdown]
# ## Embedding Similarity a.k.a Top K selection

# %%
def consine_similarity(vec1: np.ndarray, vec2: np.ndarray) -> float:
    vec1 = torch.tensor(vec1, dtype=torch.float32)
    vec2 = torch.tensor(vec2, dtype=torch.float32)
    return torch.nn.functional.cosine_similarity(vec1, vec2, dim=0).item()

# %%
for i, row in embeddings_df.iterrows():
    weighted_encoding = row['weighted_embedding']
    question_encoding = question_df.loc[question_df['question_id'] == row['question_id'], 'question_embedding'].values[0]
    similarity = consine_similarity(weighted_encoding, question_encoding)
    embeddings_df.at[i, 'similarity'] = similarity

# %%
def batch_cosine_similarity(embeddings_df: pd.DataFrame, question_df: pd.DataFrame) -> pd.DataFrame:
    weighted_encodings = np.stack(embeddings_df['weighted_embedding'].values)
    
    question_embeddings_dict = dict(zip(
        question_df['question_id'],
        question_df['question_embedding']
    ))
    
    question_encodings = np.stack([
        question_embeddings_dict[qid] 
        for qid in embeddings_df['question_id']
    ])
    
    weighted_tensor = torch.tensor(weighted_encodings, dtype=torch.float32)
    question_tensor = torch.tensor(question_encodings, dtype=torch.float32)
    
    similarities = torch.nn.functional.cosine_similarity(
        weighted_tensor, 
        question_tensor,
        dim=1
    ).numpy()
    
    embeddings_df['similarity'] = similarities
    return embeddings_df

# %%
embeddings_df = batch_cosine_similarity(embeddings_df, question_df)

# %%
# Sort within each question_id group and display relevant columns
grouped_results = (embeddings_df
    .groupby('question_id', group_keys=False)
    .apply(lambda x: x.sort_values('similarity', ascending=False))
    .reset_index(drop=True)
)[['question_id', 'question', 'title', 'sentence', 'similarity']]

# Display results
grouped_results
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_23540\2145377020.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sort_values('similarity', ascending=False))
#                     question_id  \
# 0      5a713a5a5542994082a3e6a9
# 1      5a713a5a5542994082a3e6a9
# 2      5a713a5a5542994082a3e6a9
# 3      5a713a5a5542994082a3e6a9
# 4      5a713a5a5542994082a3e6a9
# ...                         ...
# 12803  5ae82ae555429952e35eaa71
# 12804  5ae82ae555429952e35eaa71
# 12805  5ae82ae555429952e35eaa71
# 12806  5ae82ae555429952e35eaa71
# 12807  5ae82ae555429952e35eaa71
#
#                                                 question  \
# 0      What football club plays in the area between t...
# 1      What football club plays in the area between t...
# 2      What football club plays in the area between t...
# 3      What football club plays in the area between t...
# 4      What football club plays in the area between t...
# ...                                                  ...
# 12803  Martin Patterson "Pat" Hingle was a close frie...
# 12804  Martin Patterson "Pat" Hingle was a close frie...
# 12805  Martin Patterson "Pat" Hingle was a close frie...
# 12806  Martin Patterson "Pat" Hingle was a close frie...
# 12807  Martin Patterson "Pat" Hingle was a close frie...
#
#                                   title  \
# 0      Old Trafford, Greater Manchester
# 1      Old Trafford, Greater Manchester
# 2                Trafford Bar tram stop
# 3                            Gorse Hill
# 4                Trafford Bar tram stop
# ...                                 ...
# 12803              Dirás que estoy loco
# 12804              Dirás que estoy loco
# 12805              Dirás que estoy loco
# 12806              Dirás que estoy loco
# 12807              Dirás que estoy loco
#
#                                                 sentence  similarity
# 0      Old Trafford, Greater Manchester  The crossroa...    0.708351
# 1      Old Trafford, Greater Manchester Old Trafford ...    0.567476
# 2      Trafford Bar tram stop Trafford Bar is a tram ...    0.561708
# 3      Gorse Hill  Gorse Hill shares a border with Ol...    0.513169
# 4      Trafford Bar tram stop  It opened on 15 June 1...    0.481306
# ...                                                  ...         ...
# 12803  Dirás que estoy loco  The song was originally ...    0.058856
# 12804  Dirás que estoy loco  It was released two year...    0.011634
# 12805  Dirás que estoy loco "Diras que estoy loco" is...    0.009202
# 12806  Dirás que estoy loco  It was the lead single f...   -0.000019
# 12807  Dirás que estoy loco  In 2004, the song was ra...   -0.027080
#
# [12808 rows x 5 columns]

# %%
top_10 = (grouped_results
    .groupby('question_id')
    .head(10)
    .reset_index(drop=True)
)

# %% [markdown]
# ## LLM (generating answer)

# %%
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
question_chunks = {}

# %%
for i, row in top_10.iterrows():
    question = row['question']
    if question not in question_chunks:
        question_chunks[question] = []
    question_chunks[question].append(row['sentence'])

# %%
with open(r'C:\Users\admin\Desktop\AIO\ParetoRAG\prompt\prompt_template.yaml', 'r', encoding='utf-8') as file:
    prompt_template = yaml.safe_load(file)

# %%
system_prompt = prompt_template['prompt']['pareto_rag'][0]['prompt_template']
user_prompt = prompt_template['prompt']['pareto_rag'][1]['prompt_template']

# %%
import time
from tqdm import tqdm

answers = {}

# Combine system and user prompts
for k, v in tqdm(question_chunks.items(), desc="Processing questions"):
    # Combine prompts into single user message
    combined_prompt = f"{system_prompt}\n\nQuestion: {k}\nContext: {' '.join(v)}"
    
    try:
        response = model.generate_content(
            combined_prompt,
            generation_config={
                "temperature": 0.3,
                "top_p": 0.8,
                "top_k": 40,
                "max_output_tokens": 1024,
            }
        )
        
        answers[k] = response.text
        # print(f"\nProcessed: {k[:50]}...")
        time.sleep(10)  # Rate limiting
        
    except Exception as e:
        print(f"\nError processing question '{k[:50]}...': {str(e)}")
        answers[k] = f"Error: {str(e)}"

# Create DataFrame with results
answers_df = pd.DataFrame(list(answers.items()), columns=['question', 'answer'])

# %%
final_df = answers_df.head(41)
final_df['ground_truth'] = df['answer'].head(41).values
final_df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_26528\1954276991.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['ground_truth'] = df['answer'].head(41).values
#                                              question  \
# 0   What football club plays in the area between t...
# 1   Alvaro Mexia had a diplomatic mission with whi...
# 2   What is the name of the fight song of the univ...
# 3   Who has written more than 300 papers, Semyon A...
# 4   Who was the writer of These Boots Are Made for...
# 5    who is younger Keith Bostic or Jerry Glanville ?
# 6   Which board game was published most recently, ...
# 7   Who was born first, Erika Jayne or Marco Da Silva
# 8   What film was written and directed by Joby Har...
# 9   What american actress/singer born in 1956 reco...
# 10  Where is the company that Sachin Warrier worke...
# 11  Which American music star appeared as a guest ...
# 12  Born on 6 March 1937, this man was also a citi...
# 13  What retailer in ABQ Uptown is headquarted in ...
# 14  Which came to market first, "Hey Pa! There's a...
# 15  Ralph Hefferline was a psychology professor at...
# 16  Brown State Fishing Lake is in a country that ...
# 17  What major truck road is located in Backford C...
# 18  Considered the strongest recorded tropical cyc...
# 19  Alfred Balk served as the secretary of the Com...
# 20  What podcast was the cheif executive officer o...
# 21  In which year was the King who made the 1925 B...
# 22  Which was fought earlier in our nation's histo...
# 23  What was the Roud Folk Song Index of the nurse...
# 24  David Huntsinger has worked with this gospel s...
# 25  Where are Teide National Park and Garajonay Na...
# 26  What race track in the midwest hosts a 500 mil...
# 27  Which song was behind the third single on the ...
# 28  What American professional Hawaiian surfer bor...
# 29  What nationality were social anthropologists A...
# 30  Flyboys stars which actor who was nominated fo...
# 31  Which English musician is known for both the s...
# 32  Which Netflix series "Unbreakable" character i...
# 33  A Japanese manga series based on a 16 year old...
# 34  Tefik Selim Mborja was a part of a party that ...
# 35  Who was the captain of the only battleship to ...
# 36  Which dog's ancestors include Gordon and Irish...
# 37  What was the 58th quadrennial American preside...
# 38  What year was the film that starred the compos...
# 39  Who was Chamberlain and Colonel of the militar...
# 40  One Raffles Place is one of the tallest skyscr...
#
#                                                answer  \
# 0                            Manchester United F.C.\n
# 1                                               Ais\n
# 2   The provided text does not contain the name of...
# 3                                  Patrick Corrigan\n
# 4   Lee Hazlewood wrote "These Boots Are Made for ...
# 5   Keith Bostic was born on January 17, 1961.  Th...
# 6   The provided text states that "The Settlers of...
# 7                                       Erika Jayne\n
# 8                            Robin Hood (2018 film)\n
# 9                                      Paige O'Hara\n
# 10  Mumbai\n**Reasoning:** The provided text state...
# 11                                    Janet Jackson\n
# 12                                 William Bonfield\n
# 13                                             Lush\n
# 14             "Hey Pa! There's a Goat on the Roof"\n
# 15                                    New York City\n
# 16  The provided text states that Brown State Fish...
# 17                                       A5117 road\n
# 18  The provided text states that Cyclone Gonu is ...
# 19  The provided text states that Alfred Balk serv...
# 20                                      The Drop-In\n
# 21  The provided text states that the 1925 Birthda...
# 22                               Seven Days Battles\n
# 23  The provided text does not contain information...
# 24  The provided text mentions many artists David ...
# 25  Teide National Park is located in Tenerife (Ca...
# 26  The provided text does not contain the answer ...
# 27                                    Chattahoochee\n
# 28                               John John Florence\n
# 29                                          British\n
# 30                                     James Franco\n
# 31                                  George Harrison\n
# 32                                    Kimmy Schmidt\n
# 33  The provided text states that *I"s* is written...
# 34                                             1992\n
# 35  The provided text states that the USS New Jers...
# 36                                    Scotch Collie\n
# 37         2016 United States presidential election\n
# 38                                             2007\n
# 39                            Charles Hastings Judd\n
# 40                              Bank of China Tower\n
#
#                         ground_truth
# 0                                yes
# 1                  Chief of Protocol
# 2                          Animorphs
# 3                                 no
# 4   Greenwich Village, New York City
# 5                   YG Entertainment
# 6                      Eenasul Fateh
# 7                       3,677 seated
# 8                   Terry Richardson
# 9                                yes
# 10                       Kansas Song
# 11                    David Weissman
# 12                              1999
# 13                                no
# 14                 from 1986 to 2013
# 15                             9,984
# 16     the North Atlantic Conference
# 17                               yes
# 18                   1969 until 1974
# 19       Robert Erskine Childers DSC
# 20                   Pedro Rodríguez
# 21                             Sonic
# 22            keyboard function keys
# 23                   Badly Drawn Boy
# 24           World's Best Goalkeeper
# 25              Barton Lee Hazlewood
# 26                              1838
# 27                               yes
# 28                   Henry J. Kaiser
# 29                   Arena of Khazan
# 30                              2000
# 31                    Fujioka, Gunma
# 32                    Charles Eugène
# 33                                no
# 34                   Letters to Cleo
# 35                      October 1922
# 36                              2000
# 37                      World War II
# 38                                no
# 39                     New York City
# 40                     Scotch Collie
